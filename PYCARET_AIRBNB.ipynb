# %%
import numpy as np
import pandas as pd
import plotly.express as px
from plotly.offline import init_notebook_mode
import plotly.io as pio
pio.renderers.default = 'notebook'
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000
from sklearn import linear_model
import df_summary
from pycaret.regression import *

# %%
data = pd.read_csv(r"C:\Users\gabri\Downloads\AB_NYC_2019.csv\AB_NYC_2019.csv")

# %%
data.drop("neighbourhood",axis=1, inplace=True)

# %%
data2 = np.array_split(data, 5)

# %%
data2[0]
# Out:
#            id                                              name   host_id  \
# 0        2539                Clean & quiet apt home by the park      2787
# 1        2595                             Skylit Midtown Castle      2845
# 2        3647               THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3        3831                   Cozy Entire Floor of Brownstone      4869
# 4        5022  Entire Apt: Spacious Studio/Loft by central park      7192
# ...       ...                                               ...       ...
# 9774  7512240        Charming Top Floor Apartment w/ Roof Patio  39355825
# 9775  7512407                  Heart of Williamsburg w/Backyard  23584870
# 9776  7512811                        A True Brooklyn experience  13873590
# 9777  7512967                Master Bedroom w/ private bathroom   1497263
# 9778  7514135                     1 Bedroom, Bushwick, Brooklyn  37407363
#
#         host_name neighbourhood_group  latitude  longitude        room_type  \
# ...

# %%
#clf1 = setup(data2[0], target = 'neighbourhood_group')
reg1 = setup(data2[0], target = 'price')
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
# #T_f19b8ef7_0fbd_11eb_b277_d8c4975bdc14row4_col1{
#             background-color:  yellow;
#         }</style><table id="T_f19b8ef7_0fbd_11eb_b277_d8c4975bdc14" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f19b8ef7_0fbd_11eb_b277_d8c4975bdc14level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f19b8ef7_0fbd_11eb_b277_d8c4975bdc14row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_f19b8ef7_0fbd_11eb_b277_d8c4975bdc14row0_col1" class="data row0 col1" >707</td>
#             </tr>
#             <tr>
#                         <th id="T_f19b8ef7_0fbd_11eb_b277_d8c4975bdc14level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm                  Support Vector Machine
# knn                   K Neighbors Regressor
# dt                            Decision Tree
# rf                            Random Forest
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# ...

# %%
lr = create_model('lasso')
# Out:
# <style  type="text/css" >
# #T_55e729f0_0fbe_11eb_baf8_d8c4975bdc14row10_col0,#T_55e729f0_0fbe_11eb_baf8_d8c4975bdc14row10_col1,#T_55e729f0_0fbe_11eb_baf8_d8c4975bdc14row10_col2,#T_55e729f0_0fbe_11eb_baf8_d8c4975bdc14row10_col3,#T_55e729f0_0fbe_11eb_baf8_d8c4975bdc14row10_col4,#T_55e729f0_0fbe_11eb_baf8_d8c4975bdc14row10_col5{
#             background:  yellow;
#         }</style><table id="T_55e729f0_0fbe_11eb_baf8_d8c4975bdc14" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_55e729f0_0fbe_11eb_baf8_d8c4975bdc14level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
plot_model(lr)

# %%
plot_model(lr, plot = 'feature')

# %%
rc = create_model('ridge')
# Out:
# <style  type="text/css" >
# #T_c0eb6a18_0fbb_11eb_b1f2_d8c4975bdc14row10_col0,#T_c0eb6a18_0fbb_11eb_b1f2_d8c4975bdc14row10_col1,#T_c0eb6a18_0fbb_11eb_b1f2_d8c4975bdc14row10_col2,#T_c0eb6a18_0fbb_11eb_b1f2_d8c4975bdc14row10_col3,#T_c0eb6a18_0fbb_11eb_b1f2_d8c4975bdc14row10_col4,#T_c0eb6a18_0fbb_11eb_b1f2_d8c4975bdc14row10_col5,#T_c0eb6a18_0fbb_11eb_b1f2_d8c4975bdc14row10_col6{
#             background:  yellow;
#         }</style><table id="T_c0eb6a18_0fbb_11eb_b1f2_d8c4975bdc14" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
#tuned_rc = tune_model(rc)
plot_model(rc, plot = 'confusion_matrix')

# %%
plot_model(rc, plot = 'boundary')

# %%
plot_model(rc, plot = 'feature')

# %%
interpret_model(rc)

# %%
best_model = compare_models()
# Out:
# IntProgress(value=0, description='Processing: ', max=176)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      19:11:42
# Status     . . . . . . . . . . . . . . . . . .          Fitting Fold 3 of 10
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Classifier
# ETC        . . . . . . . . . . . . . . . . . .       86.75 Minutes Remaining
#                              Model  Accuracy  AUC  Recall   Prec.      F1  \
# 0         Decision Tree Classifier    0.9984  0.0  0.9937  0.9984  0.9984
# 1         Random Forest Classifier    0.9743  0.0  0.7021  0.9724  0.9711
# 2             Ada Boost Classifier    0.8958  0.0  0.8989  0.9007  0.8951
# 3                 Ridge Classifier    0.7515  0.0  0.3307  0.7170  0.7137
# 4              Logistic Regression    0.4821  0.0  0.2121  0.4406  0.4551
# 5           K Neighbors Classifier    0.4773  0.0  0.2175  0.4487  0.4578
# 6                      Naive Bayes    0.4768  0.0  0.2113  0.4575  0.4144
# ...
